# %%
import pathlib, sys
import pandas as pd
from pathlib import Path

DIR_RAIZ = Path.cwd().parent # subir 1 nivel desde Actual Working Directori (cwd)

if str(DIR_RAIZ) not in sys.path: # si el directorio raiz no está en sys.path
    sys.path.append(str(DIR_RAIZ)) # agrega el directorio raiz a sys.path para que se pueda importar soporte.py

from src import soporte as sp # importa src/soporte.py

pd.options.display.float_format = "{:,.2f}".format # Formato de impresión para floats (sólo estética)
pd.set_option('display.max_columns', None) # muestra todas las columnas

# # Autoreload para reflejar cambios en soporte.py sin reiniciar kernel
# %load_ext autoreload
# %autoreload 2

# %%
# Ruta a los CSV 
DIR_DATA_RAW = DIR_RAIZ / "data" / "raw" # Con pathlib no se concatenan rutas con +. Se unen con el operador / (o con joinpath).
DIR_DATA_RAW.resolve() # muestra la ruta absoluta

df_list = sp.cargar_df_list_desde_directorio_csv(DIR_DATA_RAW) 

# Con detalles de rutas. encodings y separadores
# df_list, csv_paths, encs, seps = sp.cargar_df_list_desde_directorio_csv(DIR_DATA_RAW, devolver_detalle=True)
# Out:
# WindowsPath('C:/Users/victo/Desktop/DATA_RETAIL/data/raw')

# %%
df_list_norm = sp.normalizar_columnas_df_list(df_list)
# Out:
# [INFO] Normalizadas columnas en DF 0:
#    -   'Order ID' -> 'order_id'
#    -   'Date' -> 'date'
#    -   'Status' -> 'status'
#    -   'Fulfilment' -> 'fulfilment'
#    -   'Sales Channel ' -> 'sales_channel'
#    -   'ship-service-level' -> 'ship_service_level'
#    -   'Style' -> 'style'
#    -   'SKU' -> 'sku'
#    -   'Category' -> 'category'
#    -   'Size' -> 'size'
#    -   'ASIN' -> 'asin'
#    -   'Courier Status' -> 'courier_status'
#    -   'Qty' -> 'qty'
#    -   'Amount' -> 'amount'
#    -   'ship-city' -> 'ship_city'
#    -   'ship-state' -> 'ship_state'
#    -   'ship-postal-code' -> 'ship_postal_code'
#    -   'ship-country' -> 'ship_country'
#    -   'promotion-ids' -> 'promotion_ids'
#    -   'B2B' -> 'b2b'
#    -   'fulfilled-by' -> 'fulfilled_by'
#    -   'Unnamed: 22' -> 'unnamed:_22'
# [INFO] Normalizadas columnas en DF 1:
#    -   'DATE' -> 'date'
#    -   'Months' -> 'months'
#    -   'CUSTOMER' -> 'customer'
#    -   'Style' -> 'style'
# ...

# %%
df_1 = df_list_norm[0].copy()    # copia del primer dataframe normalizado
df_1
# Out:
#          index             order_id      date                        status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df_2 = df_list_norm[1].copy()    # copia del segundo dataframe normalizado
df_2
# Out:
#        index      date    months            customer     style  \
# 0          0  06-05-21    Jun-21  REVATHY LOGANATHAN   MEN5004
# 1          1  06-05-21    Jun-21  REVATHY LOGANATHAN   MEN5004
# 2          2  06-05-21    Jun-21  REVATHY LOGANATHAN   MEN5004
# 3          3  06-05-21    Jun-21  REVATHY LOGANATHAN   MEN5009
# 4          4  06-05-21    Jun-21  REVATHY LOGANATHAN   MEN5011
# ...      ...       ...       ...                 ...       ...
# 37427  37427    AVIN    03-31-22              Mar-22  PJNE3423
# 37428  37428    AVIN    03-31-22              Mar-22  PJNE3404
# 37429  37429    AVIN    03-31-22              Mar-22  PJNE3423
# 37430  37430    AVIN    03-31-22              Mar-22    SET290
# 37431  37431    AVIN    03-31-22              Mar-22  SHIPPING
#
#                    sku  size      pcs     rate gross_amt
# 0         MEN5004-KR-L     L     1.00   616.56    617.00
# 1        MEN5004-KR-XL    XL     1.00   616.56    617.00
# ...

# %%
df_3 = df_list_norm[2].copy()    
df_3
# Out:
#       index       sku_code design_no.  stock       category size color
# 0         0    AN201-RED-L      AN201   5.00  AN : LEGGINGS    L   Red
# 1         1    AN201-RED-M      AN201   5.00  AN : LEGGINGS    M   Red
# 2         2    AN201-RED-S      AN201   3.00  AN : LEGGINGS    S   Red
# 3         3   AN201-RED-XL      AN201   6.00  AN : LEGGINGS   XL   Red
# 4         4  AN201-RED-XXL      AN201   3.00  AN : LEGGINGS  XXL   Red
# ...     ...            ...        ...    ...            ...  ...   ...
# 9266   9266            NaN        NaN    NaN            NaN  NaN   NaN
# 9267   9267            NaN        NaN    NaN            NaN  NaN   NaN
# 9268   9268            NaN        NaN    NaN            NaN  NaN   NaN
# 9269   9269            NaN        NaN    NaN            NaN  NaN   NaN
# 9270   9270            NaN        NaN    NaN            NaN  NaN   NaN
#
# [9271 rows x 7 columns]
